# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhansaif-Khan/Practice/blob/main/APP_pract_no_2_inheri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#    Single Inheritance   #
# Parent class
class Animal:
    def speak(self):
        print("Animal makes a sound")

# Child class (inherits Animal)
class Dog(Animal):
    def bark(self):
        print("Dog barks")

# Create object of child class
d = Dog()

# Access parent class method
d.speak()

# Access child class method
d.bark()
# Out:
# Animal makes a sound
# Dog barks

# %%
# Multilevel Inheritance
class Grandparent:
    def show_grandparent(self):
        print("Grandparent class")

class Parent(Grandparent):
    def show_parent(self):
        print("Parent class")

class Child(Parent):
    def show_child(self):
        print("Child class")

c = Child()
c.show_grandparent()
c.show_parent()
c.show_child()

# %%
# Multiple Inheritance #
class Father:
    def show_father(self):
        print("Father class")

class Mother:
    def show_mother(self):
        print("Mother class")

class Child(Father, Mother):
    def show_child(self):
        print("Child class")

c = Child()
c.show_father()
c.show_mother()
c.show_child()
# Out:
# I am an Amphibian named Froggy.
# I can walk.
# I can swim.

# %%
#  Hierarchical Inheritance
class Animal:
    def sound(self):
        print("Animal makes sound")

class Dog(Animal):
    def bark(self):
        print("Dog barks")

class Cat(Animal):
    def meow(self):
        print("Cat meows")

d = Dog()
c = Cat()

d.sound()
d.bark()

c.sound()
c.meow()
# Out:
# I have a grandparent trait.
# I have a parent trait.
# I have a child trait.

# %%
# Hybrid
class A:
    def show_A(self):
        print("Class A")

class B(A):
    def show_B(self):
        print("Class B")

class C(A):
    def show_C(self):
        print("Class C")

class D(B, C):
    def show_D(self):
        print("Class D")

d = D()
d.show_A()
d.show_B()
d.show_C()
d.show_D()
# Out:
# I can move.
# I drive on roads.
# I can move.
# I sail on water.
