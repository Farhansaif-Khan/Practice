# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhansaif-Khan/Practice/blob/main/Advance_Py_practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Name Farhan Khan , sy1, APP practical 1
# abs function

x= input("enter -ve number")
print(abs(x))
# Out:
# 20

# %%
# all function

lst = {1,2,3,4}
print(all(lst))
# Out:
# True

# %%
# any function

lst = {"True",0}
print(any(lst))
# Out:
# True

# %%
#ascii function

x= input("enter something")
print(ascii(x))
# Out:
# enter something123
# '123'

# %%
# bin function
x= input("enter a number: ")
print(bin(int(x)))
# Out:
# enter a number7
# 0b111

# %%
# Bool func
x= input("enter a number: ")
print(bool(int(x)))
# Out:
# enter a number: 1
# True

# %%
# byte array func
x= input("enter a number: ")
print(bytearray(int((x))))
# Out:
# enter a number: 4
# bytearray(b'\x00\x00\x00\x00')

# %%
# bytes func
x= input("enter a number: ")
print(bytes(int((x))))
# Out:
# enter a number: 5
# b'\x00\x00\x00\x00\x00'

# %%
# callable func
def fun():
    pass

print(callable(fun))
# Out:
# True

# %%
# chr() function
print((chr(71)))
# Out:
# G

# %%
# classmethod
class fk:
  x = 10
  @classmethod
  def show(cls):
    return cls.x

print(fk.show())
# Out:
# 10

# %%
# compile function
x = compile("a=5\nprint(a)","test","exec")
exec(x)
# Out:
# 5

# %%
# complex function
print(complex(4,2))
# Out:
# (4+2j)

# %%
#to delete attribute of obj
class a:
  x=5
delattr(a,"x")
print(hasattr(a,"x"))
# Out:
# False

# %%
# dict ()
d = dict(a=1 , b=2)
print(d)
# Out:
# {'a': 1, 'b': 2}

# %%
#dir()
print(dir(5))
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'is_integer', 'numerator', 'real', 'to_bytes']

# %%
# divmod()
print(divmod(10,3))
# Out:
# (3, 1)

# %%
# enumerate ()
for i,v in enumerate("abc"): print(i,v)
# Out:
# 0 a
# 1 b
# 2 c

# %%
#  eval func
print(eval("2+5"))
# Out:
# 7

# %%
# exec()
exec("a=4\nprint(a)")
# Out:
# 4

# %%
# filter to exclude items in iteration
def even (x): return x%2==0
print(list(filter(even,[1,2,3,4])))
# Out:
# [2, 4]

# %%
# float(3)
float(3)
# Out:
# 3.0

# %%
# format
print(format(3.14267,".2f"))
# Out:
# 3.14

# %%
# frozenset
f = frozenset([1,2,3])
print(f)
# Out:
# frozenset({1, 2, 3})

# %%
# getattr
class a: x=10
print(getattr(a,"x"))
# Out:
# 10

# %%
# globals
x=10
print("x" in globals())
# Out:
# True

# %%
# hasattr
class a: x=10
print(hasattr(a,"x"))
# Out:
# True

# %%
# hash
print(hash("abc"))
# Out:
# -5596467820315440329

# %%
# help()
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating-point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...

# %%
# hex()
hex(6)
# Out:
# '0x6'

# %%
# id()
x=2
print(id(x))
# Out:
# 11654408

# %%
# input
x= input("Enter input:")
print(x)
# Out:
# Enter input:4
# 4

# %%
# int()
print(int("10"))
# Out:
# 10

# %%
# isinstance
print(isinstance(5,int))
# Out:
# True

# %%
# issubclass
class p: pass
class c(p):pass
print(issubclass(c,p))
# Out:
# True

# %%
# iter()
it = iter([1,2,3])

# %%
# len()
print(len([1,2,3]))
# Out:
# 3

# %%
# list()
l = list((1,2,3))

# %%
# locals()
print(locals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', '# iter()\nit = iter([1,2,3])', '# iter()\nit = iter([1,2,3])', '# len()\nprint(len([1,2,3]))', '# len()\nprint(len([1,2,3]))', '# list()\nl = list((1,2,3))\n\n# locals()\nprint(locals())\n\n# map()\nprint(list(map(lambda x:x*x, [1,2,3])))', '# list()\nl = list((1,2,3))\n\n# locals()\nprint(locals())\n\n# map()\nprint(list(map(lambda x:x*x, [1,2,3])))', '# list()\nl = list((1,2,3))\n\n# locals()\nprint(locals())\n\n# map()\nprint(list(map(lambda x:x*x, [1,2,3])))', '# map()\nprint(list(map(lambda x:x*x, [1,2,3])))', '# locals()\nprint(locals())'], '_oh': {}, '_dh': ['/content'], 'In': ['', '# iter()\nit = iter([1,2,3])', '# iter()\nit = iter([1,2,3])', '# len()\nprint(len([1,2,3]))', '# len()\nprint(len([1,2,3]))', '# 
# ...

# %%
# map()
print(list(map(lambda x:x*x, [1,2,3])))
# Out:
# [1, 4, 9]

# %%
# max()
print(max([1,5,3]))
# Out:
# 5

# %%
# memoryview()
m = memoryview(b"abc")

# %%
# min()
print(min([1,5,3]))
# Out:
# 1

# %%
# next()
print(next(iter([10,20])))
# Out:
# 10

# %%
# object()
obj = object()

# %%
# oct()
print(oct(10))
# Out:
# 0o12

# %%
# open()
f = open("file.txt", "w")

# %%
# ord()
print(ord('A'))
# Out:
# 65

# %%
# pow()
print(pow(2,3))
# Out:
# 8

# %%
# print()
print("Hello")
# Out:
# Hello

# %%
# property()
class A:
    def __init__(self,x): self._x=x
    x = property(lambda self:self._x)

# %%
# range()
r = list(range(5))

# %%
# repr()
print(repr("hi"))
# Out:
# 'hi'

# %%
# reversed()
print(list(reversed([1,2,3])))
# Out:
# [3, 2, 1]

# %%
# round()
print(round(3.6))
# Out:
# 4

# %%
# set()
s = set([1,2,3])

# %%
# setattr() with a class instance
class MyClass:
    pass
obj = MyClass()
setattr(obj, 'new', 100)
print(f"Object attribute set with setattr: {obj.new}")
d = dict(a=1 , b=2)
d['new'] = 100
print(f"Dictionary updated using direct assignment: {d}")
# Out:
# Object attribute set with setattr: 100
# Dictionary updated using direct assignment: {'a': 1, 'b': 2, 'new': 100}

# %%
# slice()
print([1,2,3,4][slice(1,3)])
# Out:
# [2, 3]

# %%
# sorted()
print(sorted([3,1,2]))
# Out:
# [1, 2, 3]

# %%
# staticmethod()
class A:
    @staticmethod
    def show(): print("Hi")

# %%
# str()
s = str(123)

# %%
# sum()
print(sum([1,2,3]))
# Out:
# 6

# %%
# super()
class A:
    def show(self): print("A")
class B(A):
    def show(self): super().show()

# %%
# tuple()
t = tuple([1,2,3])
print(type(t))
# Out:
# <class 'tuple'>

# %%
# type()
print(type(5))
# Out:
# <class 'int'>

# %%
# vars()
class A: x=10
print(vars(A))
# Out:
# {'__module__': '__main__', 'x': 10, '__dict__': <attribute '__dict__' of 'A' objects>, '__weakref__': <attribute '__weakref__' of 'A' objects>, '__doc__': None}

# %%
# zip()
print(list(zip([1,2],[3,4])))
# Out:
# [(1, 3), (2, 4)]
